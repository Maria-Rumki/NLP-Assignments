# %%
# !pip install spacy or pip install -U 'spacy[cuda-autodetect]'

# !python -m spacy download en_core_web_sm #trained using cnn

# !python -m spacy download en_core_web_md #has word embedding (gloVe); trained using cnn

# !python -m spacy download en_core_web_trf #everything is trained using transformer

# %% [markdown]
# ## 1. Loading Data

# %%
import pandas as pd
import numpy as np

df_resume = pd.read_csv("/content/resume.csv")

# %%
df_resume = df_resume.reindex(np.random.permutation(df_resume.index))
# df_resume = df_resume.copy().iloc[:1000, ]  # optional if your computer is fast, no need
df_resume = df_resume.copy()
df_resume.shape
# Out:
# (2484, 4)

# %% [markdown]
# ## 2. Loading Skills and Education Data

# %%
import spacy

nlp = spacy.load('en_core_web_md')
skill_path = "/content/education_skill.jsonl"

# %%
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk(skill_path)
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'entity_ruler']

# %%
doc = nlp("Chaky loves deep learning.")
doc.ents
# Out:
# (Chaky, deep learning)

# %% [markdown]
# ## 3. Extracting Skills and Education

# %%
df_resume.head()
# Out:
#             ID                                         Resume_str  \
# 167   15471999           DESIGNER STYLIST       Summary     Hi...
# 359   18001081           TEACHER           Summary      Kind a...
# 2057  12545844           PUBLIC RELATIONS ACCOUNT COORDINATOR ...
# 859   29165698           GENERAL MANAGER           Summary    ...
# 0     16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
#
#                                             Resume_html          Category
# 167   <div class="fontsize fontface vmargins hmargin...          DESIGNER
# 359   <div class="fontsize fontface vmargins hmargin...           TEACHER
# 2057  <div class="fontsize fontface vmargins hmargin...  PUBLIC-RELATIONS
# 859   <div class="fontsize fontface vmargins hmargin...           FITNESS
# 0     <div class="fontsize fontface vmargins hmargin...                HR

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# before that, let's clean our resume.csv dataframe
def preprocessing(sentence):
    
    stopwords = list(STOP_WORDS)
    doc = nlp(sentence)
    cleaned_tokens = []
    
    for token in doc:
        if token.text not in stopwords and token.pos_ != 'PUNCT' and token.pos_ != 'SPACE' and \
            token.pos_ != 'SYM':
                cleaned_tokens.append(token.lemma_.lower().strip())
                
    return " ".join(cleaned_tokens)

# %%
# random sampling
random_resume = df_resume.Resume_str.iloc[5]
random_resume[:300]
# Out:
# '         CONSULTANT           Professional Overview    Masters of Social Work Performed medical social work services for over 10 years, in multiple environments, providing patients and their families with comprehensive psychosocial assessment, crisis counseling, grief counseling, end of life counsel'

# %%
preprocessing(random_resume[:300])
# Out:
# 'consultant professional overview masters social work perform medical social work service 10 year multiple environment provide patient family comprehensive psychosocial assessment crisis counseling grief counseling end life counsel'

# %%
# let's apply to the whole dataframe
for i, row in df_resume.iterrows():
    clean_text = preprocessing(row.Resume_str)
    df_resume.at[i, 'Clean_resume'] = clean_text

# %%
df_resume.head()
# Out:
#             ID                                         Resume_str  \
# 167   15471999           DESIGNER STYLIST       Summary     Hi...
# 359   18001081           TEACHER           Summary      Kind a...
# 2057  12545844           PUBLIC RELATIONS ACCOUNT COORDINATOR ...
# 859   29165698           GENERAL MANAGER           Summary    ...
# 0     16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
#
#                                             Resume_html          Category  \
# 167   <div class="fontsize fontface vmargins hmargin...          DESIGNER
# 359   <div class="fontsize fontface vmargins hmargin...           TEACHER
# 2057  <div class="fontsize fontface vmargins hmargin...  PUBLIC-RELATIONS
# 859   <div class="fontsize fontface vmargins hmargin...           FITNESS
# 0     <div class="fontsize fontface vmargins hmargin...                HR
#
#                                            Clean_resume
# 167   designer stylist summary high achieve sales as...
# 359   teacher summary kind compassionate elementary ...
# 2057  public relation account coordinator summary pu...
# 859   general manager summary dedicate enthusiast ye...
# 0     hr administrator marketing associate hr admini...

# %% [markdown]
# ## 4. Let's really Extract Skills and Education!!

# %%
def skills_and_education(text):
    # passing the text to the nlp
    doc = nlp(text)  # note that this nlp already know skills
    
    skills = []
    education = []
    
    # looking at the ents
    for ent in doc.ents:
        # if the ent.label_ is SKILL, then we append to some list
        if ent.label_ == "SKILL":
            skills.append(ent.text)
        if ent.label_ == "EDUCATION":
            education.append(ent.text)

    # converting to list 
    skills_list = list(set(skills))
    education_list = list(set(education))

    # reversing education list to display in order
    education_list.reverse()

    return skills_list, education_list

# def unique_skills(x):
    # return list(set(x))

# %%
df_resume.head(1)
# Out:
#            ID                                         Resume_str  \
# 167  15471999           DESIGNER STYLIST       Summary     Hi...
#
#                                            Resume_html  Category  \
# 167  <div class="fontsize fontface vmargins hmargin...  DESIGNER
#
#                                           Clean_resume
# 167  designer stylist summary high achieve sales as...

# %%
df_resume['Skills_Education'] = df_resume.Clean_resume.apply(skills_and_education)
# df_resume['Skills'] = df_resume.Skills.apply(unique_skills)

# %%
df_resume.Skills_Education.iloc[0]
# Out:
# (['schedule'], ['diploma'])

# %% [markdown]
# ## 5. Visualization

# %%
set(df_resume.Category)
# Out:
# {'ACCOUNTANT',
#  'ADVOCATE',
#  'AGRICULTURE',
#  'APPAREL',
#  'ARTS',
#  'AUTOMOBILE',
#  'AVIATION',
#  'BANKING',
#  'BPO',
#  'BUSINESS-DEVELOPMENT',
#  'CHEF',
#  'CONSTRUCTION',
#  'CONSULTANT',
#  'DESIGNER',
#  'DIGITAL-MEDIA',
#  'ENGINEERING',
#  'FINANCE',
#  'FITNESS',
#  'HEALTHCARE',
#  'HR',
#  'INFORMATION-TECHNOLOGY',
#  'PUBLIC-RELATIONS',
#  'SALES',
#  'TEACHER'}

# %%
category = 'INFORMATION-TECHNOLOGY'
cond = df_resume.Category == category

df_resume_it = df_resume[cond]
df_resume_it.shape
# Out:
# (120, 6)

# %%
# skills_education = np.concatenate(df_resume_it.Skills_Education.values)

# %%
# counting
# from collections import Counter, OrderedDict

# counting = Counter(skills_education)
# counting = OrderedDict(counting.most_common(10))

# %%
# counting

# %%
# counting.shape

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize=(15, 3))
# plt.xticks(rotation =45)

# plt.bar(counting.keys(), counting.values())

# %% [markdown]
# ## 6. Name Entity Recognition

# %%
from spacy import displacy

text = df_resume_it.Clean_resume.iloc[43]

# %%
doc = nlp(text)

# %%
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'entity_ruler']

# %%
colors = {"SKILL": "linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c)", 
          "EDUCATION": "linear-gradient(#e66465, #9198e5);"}
options = {"colors": colors}

displacy.render(doc, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">information technology manager experience information technology manager
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     april 2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  current company name
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     － city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  state
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     budget planning department network administration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  implementation new technology develop company application
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  backup technical
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     support
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     80
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  user administration
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  firewall spam firewall web filter vlan vpn setup administration
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     windows
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     server
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  r2 administration
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     microsoft active directory administration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  pc
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     windows
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     windows
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  xp
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     microsoft dfs dhcp dns wsus services administration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ftp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     server
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  implementation administration
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     microsoft exchange
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     server
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  administration creation new user distribution group
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  backup
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c

# %% [markdown]
# ## 7. Let's Load the PDF (adding some realism)

# %%
# ! pip install PyPDF2

# %%
from PyPDF2 import PdfReader
# pip install PyPDF2

reader = PdfReader("/content/someone_cv.pdf")
page = reader.pages[0] #first page just for demo
text = page.extract_text()

# %%
text = preprocessing(text)

# %%
doc = nlp(text)

# %%
colors = {"SKILL": "linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c)", 
          "EDUCATION": "linear-gradient(#e66465, #9198e5);"}
options = {"colors": colors}

displacy.render(doc, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">y
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oshua bengio c.v département d’informatique et recherche opérationnelle université de montréal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  phone
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     514
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  - 343
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6804
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  yoshua.bengio@mila.quebec
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     https://mila.quebec/en/yoshua- bengio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  a.m. turing award fellow royal society
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     london
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  fellow
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     royal society canada cifar ai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chair titles distinctions
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     full
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  professor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     université de montréal department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     computer science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  operation research
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  recruit assistant prof
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1993
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  previously associate professor
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1997 2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  assistant professor
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1993 1997
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  research chair onstatistical learning
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     algorithms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2001 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  recipient
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cifar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(0.25turn, #3f87a6, #ebf8e1, #f69d3c); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ccai chair
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018 2023 1.25m$ recipient 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  a.m. turing award
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  killam prize
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     victorin québec prize
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  high distinction science province
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     québec prix d’excellence du frqnt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-alig

# %%
# collecting all the skills and education and put it into a list

skills = []
education = []

for ent in doc.ents:
    if ent.label_ == 'SKILL':
        skills.append(ent.text)
    if ent.label_ == 'EDUCATION':
        education.append(ent.text)
        
# print(set(skills))
# print(set(education))
